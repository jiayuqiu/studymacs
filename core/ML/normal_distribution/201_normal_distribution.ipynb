# %% [markdown]
# # 正态分布
#
# ## 一、基本概念
#
# 正太分布图像由数据集的 `数学期望` 与 `方差` 确定。
#
# $$ f(x) = \frac{1}{\sigma \sqrt{2\pi }} e^{- \frac{(x - \mu )^{2}}{2\sigma ^{2}}} $$
#
# - 数学期望：决定了分布的位置
# - 方差：决定了分布的幅度

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

mean = 0
std = 2
nd = stats.norm(mean, std)  # 生成正态分布

x = np.arange(-5, 5, 0.1)
y = nd.pdf(x)

print(nd.ppf([0.025,0.975]))

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("probability density")
plt.title("Normal distribution:mean=%.1f,standard deviation=%.1f"%(mean,std))
plt.show()
# Out:
# [-3.91992797  3.91992797]
